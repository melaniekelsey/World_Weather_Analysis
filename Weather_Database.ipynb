# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations by creating the variables and saving and zipping them to a file. 
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list. Enumerate gets the index of the city for logging purposes. 
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes. This is checking if we hit the 50 count mark and if so keep going, if not start over. 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city. This is concatenating the name
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities. Try-request method is like iferror, just skip and keep going. 
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | purificacion
# Processing Record 2 of Set 1 | hasaki
# Processing Record 3 of Set 1 | bengkulu
# Processing Record 4 of Set 1 | mahebourg
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | khipro
# Processing Record 8 of Set 1 | liverpool
# Processing Record 9 of Set 1 | tiksi
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | maumere
# Processing Record 12 of Set 1 | east london
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | kieta
# Processing Record 16 of Set 1 | alice springs
# Processing Record 17 of Set 1 | gashua
# Processing Record 18 of Set 1 | bourail
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | pangkalanbuun
# Processing Record 21 of Set 1 | sumter
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | auki
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | tuktoyaktuk
# Processing Record 26 of Set 1 | souillac
# Processing Record 27 of Set 1 | esperance
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | beringovskiy
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | opuwo
# Processing Record 32 of Set 1 | energetik
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | narsaq
# Processing Record 35 of Set 1 | natal
# Processing Record 36 of Set 1 | esqueda
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | provideniya
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | les cayes
# Processing Record 41 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 42 of Set 1 | ponta do sol
# Processing Record 43 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 1 | yulara
# Processing Record 45 of Set 1 | lompoc
# Processing Record 46 of Set 1 | weligama
# Processing Record 47 of Set 1 | okhotsk
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | karratha
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | coquimbo
# Processing Record 3 of Set 2 | saskylakh
# Processing Record 4 of Set 2 | roald
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | saint-joseph
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | belmonte
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | naze
# Processing Record 11 of Set 2 | big spring
# Processing Record 12 of Set 2 | shepsi
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | padang
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | sitka
# Processing Record 17 of Set 2 | asau
# Processing Record 18 of Set 2 | ahipara
# Processing Record 19 of Set 2 | kamloops
# Processing Record 20 of Set 2 | leningradskiy
# Processing Record 21 of Set 2 | port elizabeth
# Processing Record 22 of Set 2 | ponte nova
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | namanyere
# Processing Record 25 of Set 2 | norman wells
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | tautira
# Processing Record 29 of Set 2 | arlit
# Processing Record 30 of Set 2 | half moon bay
# Processing Record 31 of Set 2 | saint-philippe
# Processing Record 32 of Set 2 | llangefni
# Processing Record 33 of Set 2 | vicovu de sus
# Processing Record 34 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 2 | kruisfontein
# Processing Record 36 of Set 2 | trifesti
# Processing Record 37 of Set 2 | ostrovnoy
# Processing Record 38 of Set 2 | avarua
# Processing Record 39 of Set 2 | bubaque
# Processing Record 40 of Set 2 | marsa matruh
# Processing Record 41 of Set 2 | castro
# Processing Record 42 of Set 2 | te anau
# Processing Record 43 of Set 2 | walvis bay
# Processing Record 44 of Set 2 | mahon
# Processing Record 45 of Set 2 | mahina
# Processing Record 46 of Set 2 | nanortalik
# Processing Record 47 of Set 2 | harper
# Processing Record 48 of Set 2 | khatanga
# Processing Record 49 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 50 of Set 2 | cidreira
# Processing Record 1 of Set 3 | sidrolandia
# Processing Record 2 of Set 3 | balkanabat
# Processing Record 3 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 3 | yorkton
# Processing Record 6 of Set 3 | pangnirtung
# Processing Record 7 of Set 3 | poum
# Processing Record 8 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 3 | hilo
# Processing Record 10 of Set 3 | fort nelson
# Processing Record 11 of Set 3 | ilulissat
# Processing Record 12 of Set 3 | corpus christi
# Processing Record 13 of Set 3 | cap malheureux
# Processing Record 14 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 3 | torbay
# Processing Record 16 of Set 3 | victoria
# Processing Record 17 of Set 3 | colares
# Processing Record 18 of Set 3 | maceio
# Processing Record 19 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 3 | henties bay
# Processing Record 21 of Set 3 | pierre
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | georgetown
# Processing Record 24 of Set 3 | bealanana
# Processing Record 25 of Set 3 | bathsheba
# Processing Record 26 of Set 3 | acala
# Processing Record 27 of Set 3 | grand gaube
# Processing Record 28 of Set 3 | puerto ayora
# Processing Record 29 of Set 3 | vinh
# Processing Record 30 of Set 3 | sehithwa
# Processing Record 31 of Set 3 | brigantine
# Processing Record 32 of Set 3 | la ronge
# Processing Record 33 of Set 3 | ballina
# Processing Record 34 of Set 3 | saint george
# Processing Record 35 of Set 3 | road town
# Processing Record 36 of Set 3 | wukari
# Processing Record 37 of Set 3 | pakxan
# Processing Record 38 of Set 3 | barrow
# Processing Record 39 of Set 3 | butaritari
# Processing Record 40 of Set 3 | san patricio
# Processing Record 41 of Set 3 | marsh harbour
# Processing Record 42 of Set 3 | doha
# Processing Record 43 of Set 3 | virginia beach
# Processing Record 44 of Set 3 | pathein
# Processing Record 45 of Set 3 | port blair
# Processing Record 46 of Set 3 | tricase
# Processing Record 47 of Set 3 | stromness
# Processing Record 48 of Set 3 | changji
# Processing Record 49 of Set 3 | chokurdakh
# Processing Record 50 of Set 3 | taltal
# Processing Record 1 of Set 4 | mackenzie
# Processing Record 2 of Set 4 | dunedin
# Processing Record 3 of Set 4 | camocim
# Processing Record 4 of Set 4 | kapaa
# Processing Record 5 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 4 | govindgarh
# Processing Record 7 of Set 4 | kurikka
# Processing Record 8 of Set 4 | kolchugino
# Processing Record 9 of Set 4 | barranca
# Processing Record 10 of Set 4 | clarence town
# Processing Record 11 of Set 4 | havoysund
# Processing Record 12 of Set 4 | shenzhen
# Processing Record 13 of Set 4 | arraial do cabo
# Processing Record 14 of Set 4 | bacesti
# Processing Record 15 of Set 4 | grand-santi
# Processing Record 16 of Set 4 | dwarka
# Processing Record 17 of Set 4 | anadyr
# Processing Record 18 of Set 4 | vostok
# Processing Record 19 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 4 | badovinci
# Processing Record 21 of Set 4 | cao bang
# Processing Record 22 of Set 4 | rio gallegos
# Processing Record 23 of Set 4 | bandarbeyla
# Processing Record 24 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 4 | abu samrah
# Processing Record 26 of Set 4 | tongliao
# Processing Record 27 of Set 4 | shimoda
# Processing Record 28 of Set 4 | san rafael
# Processing Record 29 of Set 4 | namatanai
# Processing Record 30 of Set 4 | san quintin
# Processing Record 31 of Set 4 | genhe
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | meulaboh
# Processing Record 34 of Set 4 | kalmunai
# Processing Record 35 of Set 4 | mar del plata
# Processing Record 36 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 4 | klaksvik
# Processing Record 38 of Set 4 | atuona
# Processing Record 39 of Set 4 | bronnoysund
# Processing Record 40 of Set 4 | bethel
# Processing Record 41 of Set 4 | mahmudabad
# Processing Record 42 of Set 4 | ngaoundere
# Processing Record 43 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 4 | bambous virieux
# Processing Record 45 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | saint anthony
# Processing Record 47 of Set 4 | kaitangata
# Processing Record 48 of Set 4 | berlevag
# Processing Record 49 of Set 4 | kudahuvadhoo
# Processing Record 50 of Set 4 | angoche
# Processing Record 1 of Set 5 | guerrero negro
# Processing Record 2 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 5 | kamina
# Processing Record 4 of Set 5 | aklavik
# Processing Record 5 of Set 5 | kuala terengganu
# Processing Record 6 of Set 5 | burica
# City not found. Skipping...
# Processing Record 7 of Set 5 | the valley
# Processing Record 8 of Set 5 | timmins
# Processing Record 9 of Set 5 | caldwell
# Processing Record 10 of Set 5 | haines junction
# Processing Record 11 of Set 5 | pemangkat
# Processing Record 12 of Set 5 | oktyabrskiy
# Processing Record 13 of Set 5 | sakakah
# Processing Record 14 of Set 5 | bhongir
# Processing Record 15 of Set 5 | upernavik
# Processing Record 16 of Set 5 | stamsund
# City not found. Skipping...
# Processing Record 17 of Set 5 | kendal
# Processing Record 18 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 5 | tambo grande
# Processing Record 20 of Set 5 | lagoa
# Processing Record 21 of Set 5 | mount darwin
# Processing Record 22 of Set 5 | kailua
# Processing Record 23 of Set 5 | sept-iles
# Processing Record 24 of Set 5 | shasta lake
# Processing Record 25 of Set 5 | codrington
# Processing Record 26 of Set 5 | moussoro
# Processing Record 27 of Set 5 | katsuura
# Processing Record 28 of Set 5 | mahibadhoo
# Processing Record 29 of Set 5 | saldanha
# Processing Record 30 of Set 5 | fortuna
# Processing Record 31 of Set 5 | luderitz
# Processing Record 32 of Set 5 | aripuana
# Processing Record 33 of Set 5 | chernyshevskiy
# Processing Record 34 of Set 5 | pevek
# Processing Record 35 of Set 5 | valle de allende
# Processing Record 36 of Set 5 | sembakung
# Processing Record 37 of Set 5 | kutum
# Processing Record 38 of Set 5 | flinders
# Processing Record 39 of Set 5 | mbeya
# Processing Record 40 of Set 5 | altay
# Processing Record 41 of Set 5 | san roque
# Processing Record 42 of Set 5 | kyabe
# Processing Record 43 of Set 5 | mount gambier
# Processing Record 44 of Set 5 | guadalajara
# Processing Record 45 of Set 5 | broome
# Processing Record 46 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 5 | reconquista
# Processing Record 48 of Set 5 | bam
# Processing Record 49 of Set 5 | indianola
# Processing Record 50 of Set 5 | namtsy
# Processing Record 1 of Set 6 | eyl
# Processing Record 2 of Set 6 | mundra
# Processing Record 3 of Set 6 | yellowknife
# Processing Record 4 of Set 6 | lodja
# Processing Record 5 of Set 6 | cabinda
# Processing Record 6 of Set 6 | ucluelet
# Processing Record 7 of Set 6 | chumikan
# Processing Record 8 of Set 6 | ostersund
# Processing Record 9 of Set 6 | svetlaya
# Processing Record 10 of Set 6 | kavaratti
# Processing Record 11 of Set 6 | malanje
# Processing Record 12 of Set 6 | tazovskiy
# Processing Record 13 of Set 6 | iqaluit
# Processing Record 14 of Set 6 | iwanai
# Processing Record 15 of Set 6 | cherskiy
# Processing Record 16 of Set 6 | narrabri
# Processing Record 17 of Set 6 | isangel
# Processing Record 18 of Set 6 | torata
# Processing Record 19 of Set 6 | chuy
# Processing Record 20 of Set 6 | baglung
# Processing Record 21 of Set 6 | balikpapan
# Processing Record 22 of Set 6 | heihe
# Processing Record 23 of Set 6 | languyan
# Processing Record 24 of Set 6 | ribeira grande
# Processing Record 25 of Set 6 | akdagmadeni
# Processing Record 26 of Set 6 | cayenne
# Processing Record 27 of Set 6 | mecca
# Processing Record 28 of Set 6 | trelew
# Processing Record 29 of Set 6 | bay roberts
# Processing Record 30 of Set 6 | samarai
# Processing Record 31 of Set 6 | taloqan
# Processing Record 32 of Set 6 | puerto del rosario
# Processing Record 33 of Set 6 | naryan-mar
# Processing Record 34 of Set 6 | gabu
# Processing Record 35 of Set 6 | satka
# Processing Record 36 of Set 6 | gamba
# Processing Record 37 of Set 6 | port perry
# Processing Record 38 of Set 6 | labuhan
# Processing Record 39 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 40 of Set 6 | coahuayana
# Processing Record 41 of Set 6 | jardim
# Processing Record 42 of Set 6 | faanui
# Processing Record 43 of Set 6 | pudozh
# Processing Record 44 of Set 6 | nhulunbuy
# Processing Record 45 of Set 6 | inirida
# Processing Record 46 of Set 6 | yining
# Processing Record 47 of Set 6 | praia da vitoria
# Processing Record 48 of Set 6 | vila
# Processing Record 49 of Set 6 | baie-comeau
# Processing Record 50 of Set 6 | imbituba
# Processing Record 1 of Set 7 | usinsk
# Processing Record 2 of Set 7 | sola
# Processing Record 3 of Set 7 | vung tau
# Processing Record 4 of Set 7 | yumen
# Processing Record 5 of Set 7 | saint-augustin
# Processing Record 6 of Set 7 | chalus
# Processing Record 7 of Set 7 | los llanos de aridane
# Processing Record 8 of Set 7 | port lincoln
# Processing Record 9 of Set 7 | muros
# Processing Record 10 of Set 7 | ann arbor
# Processing Record 11 of Set 7 | zabid
# Processing Record 12 of Set 7 | ebano
# City not found. Skipping...
# Processing Record 13 of Set 7 | havre-saint-pierre
# Processing Record 14 of Set 7 | rosarito
# Processing Record 15 of Set 7 | severo-kurilsk
# Processing Record 16 of Set 7 | povenets
# Processing Record 17 of Set 7 | taree
# Processing Record 18 of Set 7 | chibuto
# Processing Record 19 of Set 7 | pisco
# Processing Record 20 of Set 7 | makhinjauri
# Processing Record 21 of Set 7 | dingle
# Processing Record 22 of Set 7 | coihaique
# Processing Record 23 of Set 7 | axim
# Processing Record 24 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 7 | verkhnevilyuysk
# Processing Record 26 of Set 7 | ola
# Processing Record 27 of Set 7 | kamaishi
# Processing Record 28 of Set 7 | touros
# Processing Record 29 of Set 7 | santo antonio do ica
# Processing Record 30 of Set 7 | waingapu
# Processing Record 31 of Set 7 | vanimo
# Processing Record 32 of Set 7 | port hardy
# Processing Record 33 of Set 7 | airai
# Processing Record 34 of Set 7 | lac du bonnet
# Processing Record 35 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 7 | shushtar
# Processing Record 37 of Set 7 | cururupu
# Processing Record 38 of Set 7 | sucua
# Processing Record 39 of Set 7 | grindavik
# Processing Record 40 of Set 7 | beloha
# Processing Record 41 of Set 7 | clyde river
# Processing Record 42 of Set 7 | lensk
# Processing Record 43 of Set 7 | pingliang
# Processing Record 44 of Set 7 | okakarara
# Processing Record 45 of Set 7 | norrtalje
# Processing Record 46 of Set 7 | buchanan
# Processing Record 47 of Set 7 | bilibino
# Processing Record 48 of Set 7 | avera
# Processing Record 49 of Set 7 | zhuhai
# Processing Record 50 of Set 7 | japura
# Processing Record 1 of Set 8 | turukhansk
# Processing Record 2 of Set 8 | upata
# Processing Record 3 of Set 8 | kholtoson
# Processing Record 4 of Set 8 | margate
# Processing Record 5 of Set 8 | dhidhdhoo
# Processing Record 6 of Set 8 | fukue
# Processing Record 7 of Set 8 | linchuan
# City not found. Skipping...
# Processing Record 8 of Set 8 | nouakchott
# Processing Record 9 of Set 8 | tuatapere
# Processing Record 10 of Set 8 | davila
# Processing Record 11 of Set 8 | bonavista
# Processing Record 12 of Set 8 | beterou
# Processing Record 13 of Set 8 | san juan bautista
# Processing Record 14 of Set 8 | ancud
# Processing Record 15 of Set 8 | wanning
# Processing Record 16 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 8 | dekoa
# City not found. Skipping...
# Processing Record 18 of Set 8 | abalak
# Processing Record 19 of Set 8 | amurzet
# Processing Record 20 of Set 8 | rudbar
# Processing Record 21 of Set 8 | sorland
# Processing Record 22 of Set 8 | gimli
# Processing Record 23 of Set 8 | southbridge
# Processing Record 24 of Set 8 | boa vista
# Processing Record 25 of Set 8 | longyearbyen
# Processing Record 26 of Set 8 | sarai naurang
# Processing Record 27 of Set 8 | barao de melgaco
# Processing Record 28 of Set 8 | tambul
# City not found. Skipping...
# Processing Record 29 of Set 8 | geraldton
# Processing Record 30 of Set 8 | kapit
# Processing Record 31 of Set 8 | talnakh
# Processing Record 32 of Set 8 | hamilton
# Processing Record 33 of Set 8 | waddan
# Processing Record 34 of Set 8 | veraval
# Processing Record 35 of Set 8 | menongue
# Processing Record 36 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 8 | winnemucca
# Processing Record 38 of Set 8 | plettenberg bay
# Processing Record 39 of Set 8 | andenes
# Processing Record 40 of Set 8 | namibe
# Processing Record 41 of Set 8 | pinawa
# Processing Record 42 of Set 8 | mabai
# Processing Record 43 of Set 8 | kaputa
# Processing Record 44 of Set 8 | fairbanks
# Processing Record 45 of Set 8 | maldonado
# Processing Record 46 of Set 8 | salalah
# Processing Record 47 of Set 8 | merauke
# Processing Record 48 of Set 8 | tsagan aman
# Processing Record 49 of Set 8 | artvin
# Processing Record 50 of Set 8 | gerash
# Processing Record 1 of Set 9 | qianguo
# Processing Record 2 of Set 9 | bukachacha
# Processing Record 3 of Set 9 | nadym
# Processing Record 4 of Set 9 | beyneu
# Processing Record 5 of Set 9 | hualmay
# Processing Record 6 of Set 9 | matagami
# Processing Record 7 of Set 9 | zlobin
# Processing Record 8 of Set 9 | kasongo
# Processing Record 9 of Set 9 | cuencame
# Processing Record 10 of Set 9 | yoichi
# Processing Record 11 of Set 9 | hobyo
# Processing Record 12 of Set 9 | nelson bay
# Processing Record 13 of Set 9 | nijar
# Processing Record 14 of Set 9 | evensk
# Processing Record 15 of Set 9 | serenje
# Processing Record 16 of Set 9 | svetlogorsk
# Processing Record 17 of Set 9 | mocuba
# Processing Record 18 of Set 9 | orsha
# Processing Record 19 of Set 9 | szczytno
# Processing Record 20 of Set 9 | roma
# Processing Record 21 of Set 9 | tiznit
# Processing Record 22 of Set 9 | mangrol
# Processing Record 23 of Set 9 | taoudenni
# Processing Record 24 of Set 9 | scottsbluff
# Processing Record 25 of Set 9 | canto do buriti
# Processing Record 26 of Set 9 | port augusta
# Processing Record 27 of Set 9 | kurilsk
# Processing Record 28 of Set 9 | sabang
# Processing Record 29 of Set 9 | kavieng
# Processing Record 30 of Set 9 | husavik
# Processing Record 31 of Set 9 | matara
# Processing Record 32 of Set 9 | tocopilla
# Processing Record 33 of Set 9 | lyubar
# Processing Record 34 of Set 9 | nouadhibou
# Processing Record 35 of Set 9 | grande-riviere
# City not found. Skipping...
# Processing Record 36 of Set 9 | aswan
# Processing Record 37 of Set 9 | banyo
# Processing Record 38 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 39 of Set 9 | ambilobe
# Processing Record 40 of Set 9 | palmer
# Processing Record 41 of Set 9 | olafsvik
# Processing Record 42 of Set 9 | la rioja
# Processing Record 43 of Set 9 | calca
# Processing Record 44 of Set 9 | poplar bluff
# Processing Record 45 of Set 9 | tokur
# Processing Record 46 of Set 9 | skjaerhollen
# City not found. Skipping...
# Processing Record 47 of Set 9 | severnoye
# Processing Record 48 of Set 9 | campo maior
# Processing Record 49 of Set 9 | tilichiki
# Processing Record 50 of Set 9 | helong
# Processing Record 1 of Set 10 | miramar
# Processing Record 2 of Set 10 | nassau
# Processing Record 3 of Set 10 | zelenoborskiy
# Processing Record 4 of Set 10 | labuan
# Processing Record 5 of Set 10 | necochea
# Processing Record 6 of Set 10 | makakilo city
# Processing Record 7 of Set 10 | khorramshahr
# Processing Record 8 of Set 10 | lowestoft
# Processing Record 9 of Set 10 | harij
# Processing Record 10 of Set 10 | mae sot
# Processing Record 11 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 10 | yuyao
# Processing Record 13 of Set 10 | kansanshi
# Processing Record 14 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 10 | saint-pierre
# Processing Record 16 of Set 10 | yangjiang
# Processing Record 17 of Set 10 | rio grande
# Processing Record 18 of Set 10 | gat
# Processing Record 19 of Set 10 | portland
# Processing Record 20 of Set 10 | yaan
# Processing Record 21 of Set 10 | clifton
# Processing Record 22 of Set 10 | siparia
# Processing Record 23 of Set 10 | vila franca do campo
# Processing Record 24 of Set 10 | danilovka
# Processing Record 25 of Set 10 | goundam
# Processing Record 26 of Set 10 | altagracia de orituco
# Processing Record 27 of Set 10 | tortoli
# Processing Record 28 of Set 10 | karoi
# Processing Record 29 of Set 10 | calama
# Processing Record 30 of Set 10 | jetalsar
# Processing Record 31 of Set 10 | acari
# Processing Record 32 of Set 10 | qui nhon
# Processing Record 33 of Set 10 | baguanos
# Processing Record 34 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 35 of Set 10 | scarborough
# Processing Record 36 of Set 10 | abhar
# Processing Record 37 of Set 10 | mwinilunga
# Processing Record 38 of Set 10 | cabedelo
# Processing Record 39 of Set 10 | laguna
# Processing Record 40 of Set 10 | los altos hills
# Processing Record 41 of Set 10 | richards bay
# Processing Record 42 of Set 10 | praia
# Processing Record 43 of Set 10 | thinadhoo
# Processing Record 44 of Set 10 | zeya
# Processing Record 45 of Set 10 | virovitica
# Processing Record 46 of Set 10 | kalat
# Processing Record 47 of Set 10 | mount isa
# Processing Record 48 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 49 of Set 10 | neiafu
# Processing Record 50 of Set 10 | riyadh
# Processing Record 1 of Set 11 | dzhebariki-khaya
# Processing Record 2 of Set 11 | koratla
# Processing Record 3 of Set 11 | martin
# Processing Record 4 of Set 11 | huilong
# Processing Record 5 of Set 11 | sao joao da barra
# Processing Record 6 of Set 11 | luzhou
# Processing Record 7 of Set 11 | changping
# Processing Record 8 of Set 11 | srednekolymsk
# Processing Record 9 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 11 | hambantota
# Processing Record 11 of Set 11 | san ramon
# Processing Record 12 of Set 11 | mlonggo
# Processing Record 13 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 11 | cloquet
# Processing Record 15 of Set 11 | bredy
# Processing Record 16 of Set 11 | nevel
# Processing Record 17 of Set 11 | gombe
# Processing Record 18 of Set 11 | shubarkuduk
# Processing Record 19 of Set 11 | kaiyuan
# Processing Record 20 of Set 11 | toora-khem
# Processing Record 21 of Set 11 | vysokogornyy
# Processing Record 22 of Set 11 | cedar city
# Processing Record 23 of Set 11 | jacareacanga
# Processing Record 24 of Set 11 | pacific grove
# Processing Record 25 of Set 11 | sovetskiy
# Processing Record 26 of Set 11 | ust-tarka
# Processing Record 27 of Set 11 | kaeo
# Processing Record 28 of Set 11 | bozova
# Processing Record 29 of Set 11 | russell
# Processing Record 30 of Set 11 | iskateley
# Processing Record 31 of Set 11 | wageningen
# Processing Record 32 of Set 11 | seoul
# Processing Record 33 of Set 11 | talaya
# Processing Record 34 of Set 11 | otane
# Processing Record 35 of Set 11 | quesnel
# Processing Record 36 of Set 11 | yerbogachen
# Processing Record 37 of Set 11 | svetlyy
# Processing Record 38 of Set 11 | egvekinot
# Processing Record 39 of Set 11 | vao
# Processing Record 40 of Set 11 | carupano
# Processing Record 41 of Set 11 | lakatoro
# Processing Record 42 of Set 11 | celestun
# Processing Record 43 of Set 11 | tura
# Processing Record 44 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 45 of Set 11 | kulhudhuffushi
# Processing Record 46 of Set 11 | waipawa
# Processing Record 47 of Set 11 | nayoro
# Processing Record 48 of Set 11 | dudinka
# Processing Record 49 of Set 11 | cartagena
# Processing Record 50 of Set 11 | yingcheng
# Processing Record 1 of Set 12 | glendive
# Processing Record 2 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 12 | palmeirais
# Processing Record 4 of Set 12 | panama city
# Processing Record 5 of Set 12 | saurimo
# Processing Record 6 of Set 12 | faya
# Processing Record 7 of Set 12 | grasse
# Processing Record 8 of Set 12 | wattegama
# Processing Record 9 of Set 12 | santa luzia
# Processing Record 10 of Set 12 | villazon
# Processing Record 11 of Set 12 | porto santo
# Processing Record 12 of Set 12 | rosetown
# Processing Record 13 of Set 12 | kahului
# Processing Record 14 of Set 12 | lincoln
# Processing Record 15 of Set 12 | guicheng
# City not found. Skipping...
# Processing Record 16 of Set 12 | acarau
# Processing Record 17 of Set 12 | simi
# Processing Record 18 of Set 12 | san carlos de bariloche
# Processing Record 19 of Set 12 | mashhad
# Processing Record 20 of Set 12 | havelock
# Processing Record 21 of Set 12 | laguna de perlas
# Processing Record 22 of Set 12 | turka
# Processing Record 23 of Set 12 | cascais
# Processing Record 24 of Set 12 | springfield
# Processing Record 25 of Set 12 | naberera
# Processing Record 26 of Set 12 | verkh-usugli
# Processing Record 27 of Set 12 | kodinsk
# Processing Record 28 of Set 12 | franklin lakes
# Processing Record 29 of Set 12 | san andres
# Processing Record 30 of Set 12 | champerico
# Processing Record 31 of Set 12 | alugan
# Processing Record 32 of Set 12 | adrar
# Processing Record 33 of Set 12 | aktash
# Processing Record 34 of Set 12 | melchor de mencos
# Processing Record 35 of Set 12 | komsomolskiy
# Processing Record 36 of Set 12 | urumqi
# Processing Record 37 of Set 12 | sioux lookout
# Processing Record 38 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 12 | sulangan
# Processing Record 40 of Set 12 | zhangjiakou
# Processing Record 41 of Set 12 | siavonga
# Processing Record 42 of Set 12 | chicama
# Processing Record 43 of Set 12 | mae hong son
# Processing Record 44 of Set 12 | mango
# Processing Record 45 of Set 12 | mehamn
# Processing Record 46 of Set 12 | dalvik
# Processing Record 47 of Set 12 | santa rosalia
# Processing Record 48 of Set 12 | zhigansk
# Processing Record 49 of Set 12 | del rio
# Processing Record 50 of Set 12 | antsohihy
# Processing Record 1 of Set 13 | naantali
# Processing Record 2 of Set 13 | camacha
# Processing Record 3 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 4 of Set 13 | loiza
# Processing Record 5 of Set 13 | leshukonskoye
# Processing Record 6 of Set 13 | san cristobal
# Processing Record 7 of Set 13 | bektemir
# Processing Record 8 of Set 13 | caravelas
# Processing Record 9 of Set 13 | suihua
# Processing Record 10 of Set 13 | buala
# Processing Record 11 of Set 13 | belaya gora
# Processing Record 12 of Set 13 | constitucion
# Processing Record 13 of Set 13 | wadi maliz
# Processing Record 14 of Set 13 | harbour breton
# Processing Record 15 of Set 13 | kununurra
# Processing Record 16 of Set 13 | adre
# Processing Record 17 of Set 13 | tacoronte
# Processing Record 18 of Set 13 | broken hill
# Processing Record 19 of Set 13 | oxapampa
# Processing Record 20 of Set 13 | lashio
# Processing Record 21 of Set 13 | alyangula
# Processing Record 22 of Set 13 | jalu
# Processing Record 23 of Set 13 | aizkraukle
# Processing Record 24 of Set 13 | mgachi
# Processing Record 25 of Set 13 | sur
# Processing Record 26 of Set 13 | alihe
# Processing Record 27 of Set 13 | borujerd
# Processing Record 28 of Set 13 | borogontsy
# Processing Record 29 of Set 13 | puerto quijarro
# Processing Record 30 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 13 | port hedland
# Processing Record 32 of Set 13 | koumac
# Processing Record 33 of Set 13 | florianopolis
# Processing Record 34 of Set 13 | takoradi
# Processing Record 35 of Set 13 | cabo san lucas
# Processing Record 36 of Set 13 | varkkallai
# Processing Record 37 of Set 13 | inhambane
# Processing Record 38 of Set 13 | karsun
# Processing Record 39 of Set 13 | belyy yar
# Processing Record 40 of Set 13 | mattawa
# Processing Record 41 of Set 13 | puqi
# Processing Record 42 of Set 13 | daxian
# City not found. Skipping...
# Processing Record 43 of Set 13 | east wenatchee
# Processing Record 44 of Set 13 | keskin
# Processing Record 45 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 13 | itacoatiara
# Processing Record 47 of Set 13 | shetpe
# Processing Record 48 of Set 13 | kirksville
# Processing Record 49 of Set 13 | northam
# Processing Record 50 of Set 13 | band
# Processing Record 1 of Set 14 | uruzgan
# Processing Record 2 of Set 14 | djambala
# Processing Record 3 of Set 14 | wamba
# Processing Record 4 of Set 14 | zhoucheng
# Processing Record 5 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 6 of Set 14 | rocha
# Processing Record 7 of Set 14 | aksarka
# Processing Record 8 of Set 14 | tucumcari
# Processing Record 9 of Set 14 | cravo norte
# Processing Record 10 of Set 14 | hami
# Processing Record 11 of Set 14 | kostomuksha
# Processing Record 12 of Set 14 | aanekoski
# Processing Record 13 of Set 14 | westport
# Processing Record 14 of Set 14 | saravena
# Processing Record 15 of Set 14 | sungaipenuh
# Processing Record 16 of Set 14 | forssa
# Processing Record 17 of Set 14 | acapulco
# Processing Record 18 of Set 14 | itarema
# Processing Record 19 of Set 14 | kainantu
# Processing Record 20 of Set 14 | lorengau
# Processing Record 21 of Set 14 | banjar
# Processing Record 22 of Set 14 | bowen
# Processing Record 23 of Set 14 | hovd
# Processing Record 24 of Set 14 | vardo
# Processing Record 25 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 14 | manado
# Processing Record 27 of Set 14 | quelimane
# Processing Record 28 of Set 14 | boali
# Processing Record 29 of Set 14 | redmond
# Processing Record 30 of Set 14 | snezhnogorsk
# Processing Record 31 of Set 14 | sao filipe
# Processing Record 32 of Set 14 | jennings
# Processing Record 33 of Set 14 | juneau
# Processing Record 34 of Set 14 | camacupa
# Processing Record 35 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 37 of Set 14 | chas
# Processing Record 38 of Set 14 | alexandria
# Processing Record 39 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 14 | poyarkovo
# Processing Record 41 of Set 14 | angoram
# Processing Record 42 of Set 14 | dores do indaia
# Processing Record 43 of Set 14 | porto velho
# Processing Record 44 of Set 14 | curuca
# Processing Record 45 of Set 14 | gumdag
# Processing Record 46 of Set 14 | kupang
# Processing Record 47 of Set 14 | juba
# Processing Record 48 of Set 14 | solnechnyy
# Processing Record 49 of Set 14 | vanavara
# Processing Record 50 of Set 14 | isla vista
# Processing Record 1 of Set 15 | abnub
# Processing Record 2 of Set 15 | sechura
# Processing Record 3 of Set 15 | linxia
# Processing Record 4 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 15 | batesville
# Processing Record 6 of Set 15 | banda aceh
# Processing Record 7 of Set 15 | gravdal
# Processing Record 8 of Set 15 | antalaha
# Processing Record 9 of Set 15 | santa isabel
# Processing Record 10 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 15 | helena
# Processing Record 12 of Set 15 | kankan
# Processing Record 13 of Set 15 | aras
# Processing Record 14 of Set 15 | shingu
# Processing Record 15 of Set 15 | sechelt
# Processing Record 16 of Set 15 | vila velha
# Processing Record 17 of Set 15 | porto novo
# Processing Record 18 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 15 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 20 of Set 15 | tadine
# Processing Record 21 of Set 15 | high rock
# Processing Record 22 of Set 15 | calvinia
# Processing Record 23 of Set 15 | rincon
# Processing Record 24 of Set 15 | lasa
# Processing Record 25 of Set 15 | sinnamary
# Processing Record 26 of Set 15 | hoquiam
# Processing Record 27 of Set 15 | karlskoga
# Processing Record 28 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 29 of Set 15 | elizabeth city
# Processing Record 30 of Set 15 | chimbote
# Processing Record 31 of Set 15 | carandai
# Processing Record 32 of Set 15 | gasa
# Processing Record 33 of Set 15 | deming
# Processing Record 34 of Set 15 | santa maria
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 677

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Purificacion      CO   3.8587  -74.9313     80.87        55          80
# 1        Hasaki      JP  35.7333  140.8333     77.40        68          99
# 2      Bengkulu      ID  -3.8004  102.2655     79.66        81          56
# 3     Mahebourg      MU -20.4081   57.7000     68.29        94          75
# 4    Bredasdorp      ZA -34.5322   20.0403     50.29        93           2
# 5        Khipro      PK  25.8285   69.3772     85.26        65         100
# 6     Liverpool      GB  53.4106   -2.9779     64.69        85          40
# 7         Tiksi      RU  71.6872  128.8694     34.45        75         100
# 8   New Norfolk      AU -42.7826  147.0587     60.30        76         100
# 9       Maumere      ID  -8.6199  122.2111     83.61        60          55
#
#    Wind Speed Current Description
# 0        3.85       broken clouds
# 1       25.14     overcast clouds
# 2       10.94          light rain
# 3        5.75          light rain
# 4        6.91           clear sky
# 5       14.09     overcast clouds
# 6        1.99       moderate rain
# 7       18.28     overcast clouds
# 8        5.99     overcast clouds
# 9        1.57       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
